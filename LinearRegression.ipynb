# %% [markdown]
# <a href="https://colab.research.google.com/github/Darjirohan/Data-Science/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('/content/Advertising (1).csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Univarient Analysis

# %%
plt.figure(figsize=(5,3))
sns.distplot(x=df['TV'])
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(5,3))
sns.distplot(x=df['Radio'])
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(5,3))
sns.distplot(x=df['Newspaper'])
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(5,3))
sns.distplot(x=df['Sales'])
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Bivariate Analysis

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(data=df, x='TV', y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=df, x='Radio', y='Sales')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
# pair plot
sns.pairplot(df)

# %% [markdown]
# Preprocessing the data

# %% [markdown]
# Cleaning the data
# we need to clean the data

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Outlier Detection
plt.figure(figsize=(5,3))
sns.boxplot(x=df['TV'])
# Out:
# <Axes: xlabel='TV'>

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x=df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper'>

# %%
#Feature Engineering
df.drop(columns=['Sales'])
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df=df.drop(columns=['Sales'])

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Model Building

# %%
df.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-76-2105921611.py in <cell line: 0>()
# ----> 1 x.head()
#
# NameError: name 'x' is not defined

# %% [markdown]
# It looks like the `NameError` was caused by trying to use `x` before it was defined. The data splitting code that defines `x` was executed after the cell where `x.head()` was called.
#
# To fix this, I've regenerated the `x.head()` code in a new cell here, so it runs after `x` is defined.

# %%
x.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
x.shape
# Out:
# (200, 3)

# %%
x_train.shape
# Out:
# (160, 3)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([16.29678619,  9.26361596, 19.45830733, 12.69896986,  7.35693629,
#        10.13630662, 24.05157829,  8.87047296, 17.68702804, 13.89240253,
#        12.32295085, 14.30587321, 15.55191065, 12.32493385, 12.35493367,
#        11.90781853, 16.25923093, 17.52440317, 17.19918066, 21.73587709,
#        18.3492105 ,  8.76977821, 10.57143038, 11.62914846,  6.56053195,
#        13.49937253, 22.01597073, 13.57251413, 23.24678946, 11.49494839,
#        16.83780927, 21.53825408, 10.32893524,  7.5361673 ,  9.85817806,
#         8.11664682, 13.21200505, 10.26339272, 11.94972059,  9.66124841])

# %%
y_test
# Out:
# 40     16.6
# 51     10.7
# 139    20.7
# 197    12.8
# 170     8.4
# 82     11.3
# 183    26.2
# 46     10.6
# 70     18.3
# 100    11.7
# 179    12.6
# 83     13.6
# 25     12.0
# 190    10.8
# 159    12.9
# 173    11.7
# 95     16.9
# 3      18.5
# 41     17.1
# 58     23.8
# 14     19.0
# 143    10.4
# 12      9.2
# 6      11.8
# 182     8.7
# 161    13.3
# 128    24.7
# 122    11.6
# 101    23.8
# 86     12.0
# 64     18.0
# 47     23.2
# 158     7.3
# 34      9.5
# 38     10.1
# 196     9.7
# 4      12.9
# 72      8.8
# 67     13.4
# 145    10.3
# Name: Sales, dtype: float64

# %%
lr.coef_
# Out:
# array([0.04552917, 0.18512403, 0.00119881])

# %%
lr.intercept_
# Out:
# np.float64(2.910980862854183)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9138375011080567

# %%
from sklearn.metrics import mean_absolute_error

# %%
mse = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mse)
# Out:
# Mean Absolute Error (MAE): 1.1986992501928753
